# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive/')

# ディレクトリの移動
# %cd /content/drive/My Drive/colony

# ディレクトリ内のデータの確認
# %ls
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive/colony
# colony_data/  colony_mobilenet_v3_large.ipynb  model/

# %%
# ライブラリのインポート
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

from sklearn.model_selection import train_test_split

import torch
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset
from torchvision.io import read_image
from torch.utils.data import DataLoader
from torch import nn, optim

from collections import defaultdict

'''
定数の指定
'''

# リサイズする画像サイズ
photo_size = 300

# バッチサイズ
batch_size = 8

# クラス数の定義
num_classes = 2

# 学習率
lr = 0.0001

# 学習済み
pretrained = True

# エポック数
epochs = 50

# 保存先のパス
save_path = '/content/drive/My Drive/colony/model/'

# 学習に使用する機器(device)の設定
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'デバイス：{device}')

'''
前処理
'''

# transformの設定
transform = {
    'train': transforms.Compose([
        transforms.Resize(photo_size),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomAffine(degrees=[-10, 10], translate=(0.1, 0.1), scale=(0.5, 1.5)),
        # transforms.RandomRotation(degrees=10),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]),
    'val': transforms.Compose([
        transforms.Resize(photo_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]),
}

# ImageFolderによるデータセットの作成
train_dataset = datasets.ImageFolder("./colony_data/train", transform=transform['train'])
val_dataset = datasets.ImageFolder("./colony_data/val", transform=transform['val'])

# Dataloader
dataloader = {
    'train': DataLoader(train_dataset, batch_size=batch_size, shuffle=True),
    'val': DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
}

'''
モデルの定義
'''

model = models.mobilenet_v3_large(pretrained=pretrained)
fc_in_features = model.classifier[3].in_features # 最終レイヤー関数の次元数
model.fc = nn.Linear(fc_in_features, num_classes) # 最終レイヤー関数の付け替え

# モデルをGPUに送る
model.to(device)

'''
学習
'''

# 損失関数と最適化関数の定義
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

history = defaultdict(list)

# 学習モデルの定義
def train_model(model, epochs, loss_fn, optimizer):
    
    # ベストスコアの初期化
    best_loss = np.inf
    
    # エポックループの設定
    for epoch in range(epochs):
        
        # 現在のエポック数の出力
        print(f'Epoch: {epoch+1} / {epochs}')
        print('--------------------------')
        
         # 毎エポック: 学習・検証ループの設定
        for phase in ['train', 'val']:
            
            # 学習モード、検証モードの切替
            if phase == 'train':
                model.train()
            else:
                model.eval()
            
            # 損失値のリセット
            running_loss = 0.0
            # 正解数
            corrects = 0
            # 予測値リストのリセット
            pred_list = []
            # 正解値リストのリセット
            true_list = []
            
            # dataloaderから、ミニバッチ(batch_size)単位でのデータの読み込み
            for images, labels in dataloader[phase]:
                
                # 入力データ、正解ラベルをモデルと同じdeviceへ移動
                images = images.to(device)
                labels = labels.to(device)
                
                # 勾配情報の初期化
                optimizer.zero_grad()
                
                # 学習時のみ勾配情報を有効に
                with torch.set_grad_enabled(phase=='train'):
                    
                    # モデルによる計算
                    outputs = model(images)
                    # 損失値の計算
                    loss = loss_fn(outputs, labels)
                    # 予測ラベルの算出
                    preds = torch.argmax(outputs, dim=1) # 予測値を出力
                    
                    # 学習時のみ、バックプロパゲーションとパラメータ更新
                    if phase == 'train':
                        
                        # 誤差逆伝播法により勾配の算出
                        loss.backward()
                        # optimizerのパラメータ更新
                        optimizer.step()
                    
                    # 損失値の追加
                    running_loss += loss.item() * images.size(0)
                    
                    # 正解数の追加
                    corrects += torch.sum(preds == labels.data)                    
                    
                    # 予測ラベルの追加
                    preds = preds.to('cpu').numpy()
                    pred_list.extend(preds)
                    
                    # 正解ラベルの追加
                    labels = labels.to('cpu').numpy()
                    true_list.extend(labels)
            
            # 1エポック内における損失値の平均
            epoch_loss = running_loss / len(dataloader[phase].dataset)
            
            # 正解率の算出
            accuracy = corrects.double() / len(dataloader[phase].dataset)
            
            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_accuracy'].append(accuracy)
            
            # 各評価スコアの出力
            print(f'{phase} Loss: {epoch_loss:.4f} Accuracy: {accuracy:.4f}')

            # 検証時、検証スコアとベストスコアの大小比較を行う
            if (phase == 'val') and (epoch_loss < best_loss):
                
                ## 検証スコアが改善した場合のみ以下の処理を行う
                
                # ベストスコアの更新
                best_loss = epoch_loss
                # パラメータの名前を指定
                param_name = f'{save_path}{epoch+1}_logloss_{epoch_loss:.4f}.pth'
                # パラメータの保存
                torch.save(model.state_dict(), param_name)
            
    
    # 正解率の推移をプロット
    plt.plot(history['train_accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('Accuracy')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()
    
    # ロスの推移をプロット
    plt.plot(history['train_loss'])
    plt.plot(history['val_loss'])
    plt.title('Loss')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

'''
モデルの学習と推論の実行
'''

train_model(model, epochs, criterion, optimizer)
# Out:
# デバイス：cuda
# Epoch: 1 / 50
# --------------------------
# train Loss: 3.9419 Accuracy: 0.4141
# val Loss: 4.9458 Accuracy: 0.0000
# Epoch: 2 / 50
# --------------------------
# train Loss: 0.7821 Accuracy: 0.7374
# val Loss: 3.3841 Accuracy: 0.0909
# Epoch: 3 / 50
# --------------------------
# train Loss: 0.4503 Accuracy: 0.8182
# val Loss: 2.3894 Accuracy: 0.1515
# Epoch: 4 / 50
# --------------------------
# train Loss: 0.4656 Accuracy: 0.7778
# val Loss: 1.8531 Accuracy: 0.3636
# Epoch: 5 / 50
# --------------------------
# train Loss: 0.4706 Accuracy: 0.8182
# val Loss: 1.3577 Accuracy: 0.6364
# Epoch: 6 / 50
# --------------------------
# train Loss: 0.4605 Accuracy: 0.7677
# val Loss: 1.1768 Accuracy: 0.6970
# Epoch: 7 / 50
# --------------------------
# train Loss: 0.3893 Accuracy: 0.8283
# val Loss: 0.7630 Accuracy: 0.8485
# Epoch: 8 / 50
# --------------------------
# train Loss: 0.2839 Accuracy: 0.8586
# val Loss: 0.5130 Accuracy: 0.9091
# Epoch: 9 / 50
# --------------------------
# train Loss: 0.2386 Accuracy: 0.8586
# val Loss: 0.3872 Accuracy: 0.9394
# Epoch: 10 / 50
# --------------------------
# train Loss: 0.4053 Accuracy: 0.8485
# val Loss: 0.2669 Accuracy: 1.0000
# Epoch: 11 / 50
# --------------------------
# train Loss: 0.2453 Accuracy: 0.9192
# val Loss: 0.2164 Accuracy: 0.9697
# Epoch: 12 / 50
# --------------------------
# train Loss: 0.2711 Accuracy: 0.8889
# val Loss: 0.2357 Accuracy: 0.9697
# Epoch: 13 / 50
# --------------------------
# train Loss: 0.3002 Accuracy: 0.8788
# val Loss: 0.2233 Accuracy: 0.9394
# Epoch: 14 / 50
# --------------------------
# train Loss: 0.2450 Accuracy: 0.8788
# val Loss: 0.2048 Accuracy: 0.9394
# Epoch: 15 / 50
# --------------------------
# train Loss: 0.2109 Accuracy: 0.9192
# val Loss: 0.1848 Accuracy: 0.9697
# Epoch: 16 / 50
# --------------------------
# train Loss: 0.1820 Accuracy: 0.9394
# val Loss: 0.1169 Accuracy: 0.9697
# Epoch: 17 / 50
# --------------------------
# train Loss: 0.0845 Accuracy: 0.9899
# val Loss: 0.0550 Accuracy: 0.9697
# Epoch: 18 / 50
# --------------------------
# train Loss: 0.1904 Accuracy: 0.9293
# val Loss: 0.0727 Accuracy: 0.9697
# Epoch: 19 / 50
# --------------------------
# train Loss: 0.1912 Accuracy: 0.9293
# val Loss: 0.1363 Accuracy: 0.9697
# Epoch: 20 / 50
# --------------------------
# train Loss: 0.1704 Accuracy: 0.9394
# val Loss: 0.0997 Accuracy: 0.9697
# Epoch: 21 / 50
# --------------------------
# train Loss: 0.1575 Accuracy: 0.9394
# val Loss: 0.0855 Accuracy: 0.9394
# Epoch: 22 / 50
# --------------------------
# train Loss: 0.1997 Accuracy: 0.9293
# val Loss: 0.0773 Accuracy: 0.9697
# Epoch: 23 / 50
# --------------------------
# train Loss: 0.3079 Accuracy: 0.8586
# val Loss: 0.0912 Accuracy: 0.9394
# Epoch: 24 / 50
# --------------------------
# train Loss: 0.1709 Accuracy: 0.9495
# val Loss: 0.0640 Accuracy: 0.9697
# Epoch: 25 / 50
# --------------------------
# train Loss: 0.1561 Accuracy: 0.9495
# val Loss: 0.1297 Accuracy: 0.9697
# Epoch: 26 / 50
# --------------------------
# train Loss: 0.1449 Accuracy: 0.9495
# val Loss: 0.0753 Accuracy: 0.9697
# Epoch: 27 / 50
# --------------------------
# train Loss: 0.1020 Accuracy: 0.9596
# val Loss: 0.0499 Accuracy: 0.9697
# Epoch: 28 / 50
# --------------------------
# train Loss: 0.1875 Accuracy: 0.9192
# val Loss: 0.0964 Accuracy: 0.9697
# Epoch: 29 / 50
# --------------------------
# train Loss: 0.1316 Accuracy: 0.9495
# val Loss: 0.1031 Accuracy: 0.9394
# Epoch: 30 / 50
# --------------------------
# train Loss: 0.1488 Accuracy: 0.9697
# val Loss: 0.1071 Accuracy: 0.9394
# Epoch: 31 / 50
# --------------------------
# train Loss: 0.2236 Accuracy: 0.8990
# val Loss: 0.1599 Accuracy: 0.9697
# Epoch: 32 / 50
# --------------------------
# train Loss: 0.1719 Accuracy: 0.9394
# val Loss: 0.1394 Accuracy: 0.9394
# Epoch: 33 / 50
# --------------------------
# train Loss: 0.2012 Accuracy: 0.8990
# val Loss: 0.1952 Accuracy: 0.9091
# Epoch: 34 / 50
# --------------------------
# train Loss: 0.1388 Accuracy: 0.9293
# val Loss: 0.1740 Accuracy: 0.9394
# Epoch: 35 / 50
# --------------------------
# train Loss: 0.0927 Accuracy: 0.9697
# val Loss: 0.1512 Accuracy: 0.9091
# Epoch: 36 / 50
# --------------------------
# train Loss: 0.1692 Accuracy: 0.9495
# val Loss: 0.1053 Accuracy: 0.9394
# Epoch: 37 / 50
# --------------------------
# train Loss: 0.1503 Accuracy: 0.9091
# val Loss: 0.1735 Accuracy: 0.9091
# Epoch: 38 / 50
# --------------------------
# train Loss: 0.2058 Accuracy: 0.8788
# val Loss: 0.2609 Accuracy: 0.9394
# Epoch: 39 / 50
# --------------------------
# train Loss: 0.1213 Accuracy: 0.9697
# val Loss: 0.1598 Accuracy: 0.9697
# Epoch: 40 / 50
# --------------------------
# train Loss: 0.1265 Accuracy: 0.9394
# val Loss: 0.1159 Accuracy: 0.9697
# Epoch: 41 / 50
# --------------------------
# train Loss: 0.1903 Accuracy: 0.9293
# val Loss: 0.0816 Accuracy: 0.9394
# Epoch: 42 / 50
# --------------------------
# train Loss: 0.0376 Accuracy: 1.0000
# val Loss: 0.1673 Accuracy: 0.9091
# Epoch: 43 / 50
# --------------------------
# train Loss: 0.1665 Accuracy: 0.9697
# val Loss: 0.1623 Accuracy: 0.9394
# Epoch: 44 / 50
# --------------------------
# train Loss: 0.0648 Accuracy: 0.9596
# val Loss: 0.0776 Accuracy: 0.9697
# Epoch: 45 / 50
# --------------------------
# train Loss: 0.0731 Accuracy: 0.9697
# val Loss: 0.0537 Accuracy: 0.9697
# Epoch: 46 / 50
# --------------------------
# train Loss: 0.1111 Accuracy: 0.9596
# val Loss: 0.0581 Accuracy: 1.0000
# Epoch: 47 / 50
# --------------------------
# train Loss: 0.1290 Accuracy: 0.9495
# val Loss: 0.0195 Accuracy: 1.0000
# Epoch: 48 / 50
# --------------------------
# train Loss: 0.0995 Accuracy: 0.9596
# val Loss: 0.0614 Accuracy: 0.9697
# Epoch: 49 / 50
# --------------------------
# train Loss: 0.1032 Accuracy: 0.9394
# val Loss: 0.0786 Accuracy: 0.9697
# Epoch: 50 / 50
# --------------------------
# train Loss: 0.0526 Accuracy: 0.9899
# val Loss: 0.0481 Accuracy: 0.9697
